# %%
import requests
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium .webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://naver.com')

# %%
elem = driver.find_element_by_id("query")
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_896/3659185284.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_id("query")

# %%
elem.send_keys(Keys.RETURN)

# %%
path = 
driver.find_element_by_css_selector(path).click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_896/3284896774.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(path).click()
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_896/3284896774.py in <module>
#       1 path = '#sp_nws1'
# ----> 2 driver.find_element_by_css_selector(path).click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     806             stacklevel=2,
#     807         )
# --> 808         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     809
#     810     def find_elements_by_css_selector(self, css_selector) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
# ...

# %%
html = driver.page_source

# %%
html
# Out:
# '<html lang="ko"><head><script type="text/javascript" id="www-widgetapi-script" src="https://www.youtube.com/s/player/2b718ca6/www-widgetapi.vflset/www-widgetapi.js" async=""></script><script type="text/javascript" async="" src="https://1330chat.visitkorea.or.kr/ttalk/js/ttalkDev.js" charset="UTF-8"></script><script src="https://www.youtube.com/player_api"></script><script src="https://www.youtube.com/player_api"></script><script src="https://connect.facebook.net/signals/config/2686987211544937?v=2.9.49&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script>\n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no">\n\t<title>대한민국 구석구석 - 홈</title>\n\t<meta property="og:type" content
# ...

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
url = 'https://korean.visitkorea.or.kr/search/search_list.do?keyword={}'
driver.get(url)
url
# Out:
# 'https://korean.visitkorea.or.kr/search/search_list.do?keyword={}'

# %%
# https://korean.visitkorea.or.kr/

# %%
path = "#contents > div > div.box_leftType1"

# %%
location = soup.select(path)

# %%
location
# Out:
# []

# %%
# https://korean.visitkorea.or.kr/search/search_list.do?keyword={}
# Out:
#   File "C:\Users\bitcamp\AppData\Local\Temp/ipykernel_896/1723561776.py", line 1
#     https://korean.visitkorea.or.kr/search/search_list.do?keyword={}
#           ^
# SyntaxError: invalid syntax

# %%
    url = 'https://korean.visitkorea.or.kr/search/search_list.do?keyword={}'
    search_kw = input("검색할 단어를 입력하세요 ")
    page_num = int(input("검색할 페이지를 입력하세요 "))
    url = url.format(search_kw,page_num)
    
    html = requests.get(url)
    
    soup = BeautifulSoup(html.text, 'html.parser')
    path = "#contents > div > div.box_leftType1"
    tags = soup.select(path)
    print(tags)

#     for t in tags:
#         print("제목 :",t.select('a')[1].text)
#         print(" URL : ",t.select('a')[0]['href'])
#         print("요약 :",t.select('p')[0].text)
#         print("언론사 : ",t.select('span.f_nb')[0].text)
#         print("작성 시간 : ",t.select('span.f_nb')[1].text)
#         print("-" * 100)
#         print()

# %%
    url = 'https://korean.visitkorea.or.kr/search/search_list.do?keyword={}'
    path = "#contents > div > div.box_leftType1"
    tags = soup.select(path)
tags
